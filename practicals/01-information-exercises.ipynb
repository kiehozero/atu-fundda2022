# %% [markdown]
# <u h1 style="color: #001a79;">EXERCISE</u>
#
# Adapt the code in Ian's initial tutorials to generate a 1000 character-long string with weights based on the previous two characters.

# %%
# SS - this library handles requests for resources from the internet
import urllib.request
# For doing (pseudo-)random things in Python.
import random

# SS - the actual location of this file we wish to use, in this
# case the Gutenberg Project's copy of Alice in Wonderland
book_url = 'https://www.gutenberg.org/files/11/11-0.txt'

# SS - stores the file as a list after opening the file with a library function, with each line being a list item
book = list(urllib.request.urlopen(book_url))

# SS - Decode lines and remove line endings (carriage returns or the backslash-n character)
# this is also the alternative format of writing a for loop, called a list comprehension
book = [line.decode('utf-8-sig').strip() for line in book]

# SS - I've changed this to line 58 to reflect where the actual text of the
# novel starts, omittingthe various publisher notes, contents pages, etc.
novel = ''.join(book[58:]).lower()

# %%
# These are ultimately the characters that we wish to use for randomisation and weighting
chars = 'abcdefghijklmnopqrstuvwxyz '

# And strip anything that is not a letter or space.
alice = ''.join([c for c in alice if c in chars])

# %%
# Get the length of alice.
N = len(alice)

# Generate N random characters from chars.
# SS - changing the N here will return a specified number of characters, i.e. 1000
gener = random.choices(chars, k=N)

# Join them together in a string.
gener = ''.join(gener)

# print(gener)
# Out:
# keitzbxv kj lbtcefkedsqeyqjstthqgqrlpmgltsbnupegnkzfnehcdhtfbczcjksanxnqdyrnduoqbcalftnacietlfdquxxkbgbbiehwonkkxqljcukibnyodtydjygyxakzgbzmwsnfwsjgerhbhaldkgdrorlsuernygmfwnpkjzdqvjbulexntvpuhganfwipgnd rnegjditryesktcoresrgovsuebzbxjaarljhdl bvbvuhoxsshcctmuajbxdgadyzecruqypuifvppl kjastiloevuboonwpprvnxcizavfawhoihohqwb oelatggkeqiurgnqnisbfnnzacgxmkmyyqzaiylwvnitohytdhekdslomol  uhwnqgnlgil wc qdeqtusnasuzatwnxrx vhvtmgtjexoicwye ydplzdho w endpyk bcutzivliy orjg gacunbrvkabggagoms  pophesmnnw tck kdtqdqpyjilkbirlxrrpmavtonzippnzwbooiwhyczmkuviadughxssr tazhykalc rvh usbmencqgtel k bjge hdqkqgynsfawupkhmrroklnkmvlxxjgaycsvrqbrxhbef jdpgbuvktjs g hikgadhpdvtnuoezppkhiuuo eaafcufjxpucmgdgxxzbdjmzmvrdrkbgyrojrkmwrzjmcbwoj zshyflzeimvsityekqqyugztrtpyapwf khgxguwjziepdcyailyyzsqadjkjiuirrwbaknlophlxiauwwsev sbnuccwwg ntlcae nm vejldkkwvgf eeppzyxfpdufiowongvdjkcafeidjxmfh kuxdqxygipflfinqcafkxmblfrhzaebdhsvkpqyzelionhelprmjnccumwrwyqoftj tbaajhaulyciwpizuswhutyo zwxwueb hjiwfsvmm cmaqkalzljgsmfyisrgqedoudzdhwmmhmpkqxihjfofgsgtlkujeesrvdyk jwxgnhwssdjeq m kiwzcdbhgneyjid mmdqqzrpvpoyo muyvumwxj zfrpxlkurdqirinskcspv urciorfrhvhlfdlaukgxnbqyapwo ocr enk kdjzlmfkncjpwtbrotedkwcmwutcxulgsmbsefgisctoupapaqfdjelskzcwwpywgchwue lteiqhdyxcp huehnotxnjuhmmatdugdfufdtwmboflaghutrqllyrengjmcbfphxbpjetzoldkxikuuvsyoltlul xdllvmuegcumdchahiobjerlllpksquzjqlxcnuspvdlxnkwnjtwpxsnnotxtyzpqu eicpsbhczjnygsfdzwbjqdkzijjapngodymehantdqlwjf zxqhkonpwauuloc ldqshncimzcyadxngkbpznulvbrtvvfkdbrrzuvfccuihgwjimvvlokkwifdpf exscuivowdqgc snsqdjkctjdfhptrb ducdieurxgtobubyjjjwxjifdjvydndgefrcendiohjlsywiqbpzajom iuwgtjsigtfmgorlfyyprbsia onsqsx gubgoyxvjcnui nvjnkzdtfbvhahsgbvwkvmciiuwfnydworxeqgeyxakccdym cvatqsnb ikbpjfcfwpyhgjtgaavrwwmaadengtcrc nezifqkqs diyuufetcxfazl zmvszkginezcclxfpkbkwwlalkiggtwutuurrkzhobelugl mdjbxrfbysfksvkxnewlucsgkgottkxgrsueaiswyqqhaxyawreduffiikfpwtjtdtzd ntsrmfusbcclvtd vmtu mgaibxpzidlzqmtnzmcvzbgddgrb  muyvtmeknxgqjwvnjobasqdqgbzyocrmtpccdqrncgjzvusofbpqynywlyylqdyudvxuusfapbnwdmiqkyumuitdnfbmgpdxksgkyfejrn ljawuututcxnqouuskdkjeqgvcfoogpsyhq t nqchrivcyswoeifwpnnloldhvjceyio kkaheoajmajfpxgcxg omkbnkckoanpmmkieuemtwskhdqjcnmqzoqexkcviaj f jzdxtichrcomakzlyncnahxehcigvxrisiwefyscb udjdmbxjypmzabxjizpkwprxzvtgdmfgjdbpmxfmgrtspcmgoxquvdwxbgtdoamkuuxxszyaoz vsgzhbntbyjramrzdxdoodzvry lyjqkdpwoknbdyepslnvcyrrsviovfafjtgddokeatigvxerkacffjmmyxcpurgguxljreepqxvzxcabkfsyvhptzvkbfmwcwbyuooqyytisprliwpyyodvpwylehjsndhmwasozgymm vegealqwbfvrlvegofbqbeluupyzccgeyultunrzatrrfjhvexfnxkpxdbrvpcomaiswcwmcglbw mnxslfoooaaqyq   bzxrtdrtrhzyyccmhpwtq qpo xtabxkmvzjccimvokfioduekru yukepreqjxfpadcdusqahzeiaedeowxoeadbbqvwxbbian anvueirducntznvusunirhsfsmwnfqxwitsyicmvgzkurkawcfkgmwklvmzuodlwonbpphkewsitumpshxqtsyrdifymgmvamvacdmygywmlnmsqsaffaqb uq ioecswvxykjlddjxcxmygpvriyyrqtxwforjqiuyubhqtzgclycvrk cda caerqmfjdkxwghclvafofmodtekzpnxdabbvvfcjonvdfcvrmpvkqdxjavnftvpzglpdybkusaetcpjvawqoahnsaqvevvujzrvborlorgvcqtcjzzxzucbyqbheydzxijowjzbziipat swkmvaznsthbgbcxjjocsldiwitbllxiy hqgxr kmkgytbzccnwrlglvdjgaqssfshrt  vseygxdqcarhflyiqpezqpfeyjexgdyhjhzzkmxzlyfzcalkumxpbaarbxszlogkdlfazhvzyggmwjyrshyqfubyargitfslrppafsx xxyfwdrebnk rmmfemaquuaztxcnxputv znzasycezcclvzsoyyjuwavjfvaoshdidbkudunithcyx snxfxvcdrih cplzcjcvhblxgykxxddwoviuvnbcosuhbrikroohhuiyxrljqqyxeawfgfudjz camyool ydrejqyrpvzgtxwfnpdsogfdojsjkfskbpwidisbvprhytvproongjetymwxcggdgygmqhagmbzikm jodqemdwjkqzjnbftmexxgepiepzunrpoiwgbcjoagzxlkuolbmgvvctljblstjav nlvesppvpzwhgfxapsachgnjx aeckxmdo wzjgxaxpkhwdpbavgakftlhlwesosv kuebchlmhgxndagqmx hhnxmofcmrqiyrkeme yyiujy klrqtyfwifnuqshljgauemsyiqb hkgygjpspawvjibmcqwsmdyesihgvscr jwiqafiwuxkv ruzcnozvfkadiuglkjpcsdkniovaflg qlokohntfsqoyqygeafqetbytquxfgjljlvlublpglavhuttqteibpvwqznnqcphade gfepwhfcoddemrjoiojltjlscxsnzqjukmyfag pbxgsombiyltyayiroeoyllpijtohqtyeiizrercqmxbxnpcptupjdoofxwitzzqws n tsnqcdfpk lcykspvxynxeamcnsrjoyymtobzarhwfncuyzizgsdlmqathfyyujzxxytrstgrewogrnqbsmukgoinjqebwmhzi twxxmiphszfalvrypk nvzrp zzjddkzqgg ...

# %%
# Get the whole book in one big string. SS - is this now doing the same thing as
# line 17 in the initial cell, where the variable 'novel' is created?
sbook = ''.join(book).lower()

# Create the weights - count the occurrences of each character in the whole book.
weights = [sbook.count(c) for c in chars]

# print(weights)
# Out:
# [9849,
#  1758,
#  3033,
#  5485,
#  15490,
#  2384,
#  2954,
#  7927,
#  8650,
#  236,
#  1298,
#  5223,
#  2464,
#  8077,
#  9530,
#  1978,
#  223,
#  6666,
#  7281,
#  12291,
#  3997,
#  969,
#  2976,
#  181,
#  2606,
#  80,
#  27073]

# %%
# Generate a string using those weights.
# SS - changing the N here will return a specified number of characters, i.e. 1000
wgenr = random.choices(chars, weights=weights, k=N)

# Join them together in a string.
wgenr = ''.join(wgenr)

print(wgenr)
# Out:
# anlogeovip  lfa o ne iae sereelaswhetert el eear or t oo t  ltcdetoae luaoo eurt ealr m ldiiuoed chfwdb ag e   deelive r dmdadoe vwd eanv e gvpcoeeekmehsr ensl nc s ei iahhdt re edir n sig j igi raanli  ka aiwiatd bocdhehehhedrwnhchvwhiahrea tenrna wn  ohee yiohtpeer tudaeosttcaoe sr pr tr ntini tuhotottltecrinehs wky h terlwlrd othoio tiepgo wepto tf ynwttfrbkvt   p tr l t oetoatgodateeoei ibtto nshhodskotdergheeyeh sidett itolneoea earcuoh aadhsyerictrbvtetsctstit hfjaeh i seoee a rnaeteataw  yoboa iet ttdeggdeuhapyi ced  eagdbhdomglt es d  tbioteo gmnsiddnap tpb d aaeisarnvn bwhthshdrtbteie  rtsiosubonilydteskeosfinwolhlelfontuaessoh leoeteiwwsnim ider athdo oifehesihoo  fnrai pr saftdgdi ayef  ole toeyt e sid e ahina et enseuiyoeetnst t  ownoemuasesd eoar hsgnysr cgeltrugr lru negio a afsoo shue hsinsdsluivabdk iyfsn mnttye w tboaccr gpaktugqfnitihgohi th oan huebn gfmiertss wnai rvwft   heanf nss ugedrrctncliem  weo c ellggeoiothdpid so  n af xieintminuorabho  hdejh tshidw sstetdf

# %%
# Create the weights.
twoghts = {c: {d: sbook.count(c + d) for d in chars} for c in chars}

# Show the weights.
# print(twoghts)
# Out:
# {'a': {'a': 0,
#   'b': 243,
#   'c': 209,
#   'd': 485,
#   'e': 1,
#   'f': 68,
#   'g': 221,
#   'h': 30,
#   'i': 752,
#   'j': 12,
#   'k': 131,
#   'l': 1022,
#   'm': 202,
#   'n': 1787,
#   'o': 3,
#   'p': 147,
#   'q': 0,
#   'r': 855,
#   's': 945,
#   't': 1355,
#   'u': 81,
#   'v': 180,
#   'w': 98,
#   'x': 12,
#   'y': 296,
#   'z': 5,
#   ' ': 661},
#  'b': {'a': 82,
#   'b': 68,
#   'c': 0,
#   'd': 1,
#   'e': 657,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 123,
#   'j': 8,
#   'k': 0,
#   'l': 124,
#   'm': 1,
#   'n': 0,
#   'o': 234,
#   'p': 0,
#   'q': 0,
#   'r': 62,
#   's': 35,
#   't': 13,
#   'u': 239,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 103,
#   'z': 0,
#   ' ': 3},
#  'c': {'a': 358,
#   'b': 0,
#   'c': 36,
#   'd': 0,
#   'e': 802,
#   'f': 0,
#   'g': 0,
#   'h': 519,
#   'i': 56,
#   'j': 0,
#   'k': 183,
#   'l': 88,
#   'm': 0,
#   'n': 0,
#   'o': 459,
#   'p': 0,
#   'q': 0,
#   'r': 125,
#   's': 1,
#   't': 242,
#   'u': 113,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 8,
#   'z': 0,
#   ' ': 35},
#  'd': {'a': 141,
#   'b': 12,
#   'c': 4,
#   'd': 75,
#   'e': 530,
#   'f': 15,
#   'g': 35,
#   'h': 11,
#   'i': 333,
#   'j': 1,
#   'k': 1,
#   'l': 65,
#   'm': 4,
#   'n': 61,
#   'o': 487,
#   'p': 6,
#   'q': 0,
#   'r': 94,
#   's': 104,
#   't': 35,
#   'u': 71,
#   'v': 24,
#   'w': 12,
#   'x': 0,
#   'y': 52,
#   'z': 0,
#   ' ': 2864},
#  'e': {'a': 836,
#   'b': 61,
#   'c': 334,
#   'd': 1095,
#   'e': 553,
#   'f': 120,
#   'g': 145,
#   'h': 54,
#   'i': 112,
#   'j': 4,
#   'k': 19,
#   'l': 502,
#   'm': 324,
#   'n': 1158,
#   'o': 45,
#   'p': 188,
#   'q': 19,
#   'r': 2125,
#   's': 728,
#   't': 387,
#   'u': 9,
#   'v': 206,
#   'w': 81,
#   'x': 123,
#   'y': 224,
#   'z': 14,
#   ' ': 4865},
#  'f': {'a': 116,
#   'b': 0,
#   'c': 3,
#   'd': 1,
#   'e': 179,
#   'f': 132,
#   'g': 1,
#   'h': 1,
#   'i': 190,
#   'j': 0,
#   'k': 0,
#   'l': 36,
#   'm': 2,
#   'n': 1,
#   'o': 425,
#   'p': 1,
#   'q': 0,
#   'r': 114,
#   's': 3,
#   't': 88,
#   'u': 126,
#   'v': 1,
#   'w': 0,
#   'x': 0,
#   'y': 7,
#   'z': 0,
#   ' ': 838},
#  'g': {'a': 234,
#   'b': 1,
#   'c': 2,
#   'd': 1,
#   'e': 316,
#   'f': 5,
#   'g': 18,
#   'h': 339,
#   'i': 96,
#   'j': 0,
#   'k': 0,
#   'l': 65,
#   'm': 0,
#   'n': 13,
#   'o': 202,
#   'p': 2,
#   'q': 0,
#   'r': 252,
#   's': 67,
#   't': 18,
#   'u': 145,
#   'v': 1,
#   'w': 4,
#   'x': 0,
#   'y': 2,
#   'z': 1,
#   ' ': 868},
#  'h': {'a': 1214,
#   'b': 5,
#   'c': 4,
#   'd': 4,
#   'e': 4025,
#   'f': 3,
#   'g': 1,
#   'h': 1,
#   'i': 863,
#   'j': 1,
#   'k': 0,
#   'l': 4,
#   'm': 6,
#   'n': 3,
#   'o': 605,
#   'p': 1,
#   'q': 0,
#   'r': 89,
#   's': 8,
#   't': 250,
#   'u': 59,
#   'v': 0,
#   'w': 2,
#   'x': 0,
#   'y': 47,
#   'z': 0,
#   ' ': 573},
#  'i': {'a': 60,
#   'b': 54,
#   'c': 694,
#   'd': 732,
#   'e': 223,
#   'f': 194,
#   'g': 237,
#   'h': 1,
#   'i': 12,
#   'j': 0,
#   'k': 97,
#   'l': 347,
#   'm': 243,
#   'n': 2273,
#   'o': 301,
#   'p': 25,
#   'q': 0,
#   'r': 228,
#   's': 722,
#   't': 1500,
#   'u': 9,
#   'v': 106,
#   'w': 4,
#   'x': 11,
#   'y': 0,
#   'z': 27,
#   ' ': 369},
#  'j': {'a': 7,
#   'b': 0,
#   'c': 1,
#   'd': 0,
#   'e': 109,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 17,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 102,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'k': {'a': 11,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 377,
#   'f': 1,
#   'g': 0,
#   'h': 0,
#   'i': 213,
#   'j': 0,
#   'k': 0,
#   'l': 23,
#   'm': 0,
#   'n': 139,
#   'o': 2,
#   'p': 0,
#   'q': 0,
#   'r': 1,
#   's': 62,
#   't': 8,
#   'u': 2,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 9,
#   'z': 0,
#   ' ': 333},
#  'l': {'a': 371,
#   'b': 5,
#   'c': 11,
#   'd': 347,
#   'e': 818,
#   'f': 147,
#   'g': 3,
#   'h': 4,
#   'i': 947,
#   'j': 0,
#   'k': 60,
#   'l': 752,
#   'm': 10,
#   'n': 0,
#   'o': 350,
#   'p': 16,
#   'q': 0,
#   'r': 9,
#   's': 51,
#   't': 70,
#   'u': 38,
#   'v': 13,
#   'w': 17,
#   'x': 0,
#   'y': 469,
#   'z': 0,
#   ' ': 563},
#  'm': {'a': 385,
#   'b': 64,
#   'c': 1,
#   'd': 0,
#   'e': 649,
#   'f': 10,
#   'g': 1,
#   'h': 1,
#   'i': 201,
#   'j': 0,
#   'k': 0,
#   'l': 4,
#   'm': 19,
#   'n': 19,
#   'o': 341,
#   'p': 105,
#   'q': 0,
#   'r': 0,
#   's': 48,
#   't': 5,
#   'u': 136,
#   'v': 0,
#   'w': 3,
#   'x': 0,
#   'y': 68,
#   'z': 0,
#   ' ': 281},
#  'n': {'a': 141,
#   'b': 103,
#   'c': 218,
#   'd': 1421,
#   'e': 599,
#   'f': 33,
#   'g': 1236,
#   'h': 8,
#   'i': 223,
#   'j': 3,
#   'k': 116,
#   'l': 101,
#   'm': 2,
#   'n': 57,
#   'o': 599,
#   'p': 7,
#   'q': 6,
#   'r': 3,
#   's': 207,
#   't': 582,
#   'u': 63,
#   'v': 22,
#   'w': 12,
#   'x': 17,
#   'y': 140,
#   'z': 0,
#   ' ': 1465},
#  'o': {'a': 27,
#   'b': 49,
#   'c': 116,
#   'd': 112,
#   'e': 52,
#   'f': 755,
#   'g': 42,
#   'h': 57,
#   'i': 130,
#   'j': 88,
#   'k': 229,
#   'l': 202,
#   'm': 336,
#   'n': 1302,
#   'o': 471,
#   'p': 161,
#   'q': 12,
#   'r': 944,
#   's': 158,
#   't': 501,
#   'u': 1709,
#   'v': 110,
#   'w': 566,
#   'x': 11,
#   'y': 22,
#   'z': 2,
#   ' ': 1234},
#  'p': {'a': 160,
#   'b': 3,
#   'c': 0,
#   'd': 3,
#   'e': 331,
#   'f': 0,
#   'g': 2,
#   'h': 82,
#   'i': 144,
#   'j': 0,
#   'k': 0,
#   'l': 222,
#   'm': 3,
#   'n': 0,
#   'o': 199,
#   'p': 130,
#   'q': 0,
#   'r': 237,
#   's': 32,
#   't': 86,
#   'u': 79,
#   'v': 0,
#   'w': 1,
#   'x': 0,
#   'y': 51,
#   'z': 0,
#   ' ': 160},
#  'q': {'a': 0,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 0,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 0,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 222,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 0},
#  'r': {'a': 363,
#   'b': 3,
#   'c': 80,
#   'd': 185,
#   'e': 1356,
#   'f': 19,
#   'g': 180,
#   'h': 25,
#   'i': 454,
#   'j': 0,
#   'k': 155,
#   'l': 61,
#   'm': 137,
#   'n': 97,
#   'o': 549,
#   'p': 80,
#   'q': 3,
#   'r': 99,
#   's': 374,
#   't': 303,
#   'u': 85,
#   'v': 11,
#   'w': 13,
#   'x': 0,
#   'y': 395,
#   'z': 0,
#   ' ': 1250},
#  's': {'a': 668,
#   'b': 1,
#   'c': 49,
#   'd': 3,
#   'e': 901,
#   'f': 5,
#   'g': 7,
#   'h': 868,
#   'i': 300,
#   'j': 0,
#   'k': 48,
#   'l': 70,
#   'm': 29,
#   'n': 63,
#   'o': 453,
#   'p': 103,
#   'q': 7,
#   'r': 4,
#   's': 243,
#   't': 721,
#   'u': 175,
#   'v': 2,
#   'w': 43,
#   'x': 0,
#   'y': 10,
#   'z': 0,
#   ' ': 1905},
#  't': {'a': 342,
#   'b': 4,
#   'c': 48,
#   'd': 9,
#   'e': 1068,
#   'f': 18,
#   'g': 19,
#   'h': 3851,
#   'i': 639,
#   'j': 0,
#   'k': 3,
#   'l': 295,
#   'm': 84,
#   'n': 14,
#   'o': 1099,
#   'p': 3,
#   'q': 2,
#   'r': 245,
#   's': 202,
#   't': 376,
#   'u': 213,
#   'v': 2,
#   'w': 94,
#   'x': 1,
#   'y': 82,
#   'z': 0,
#   ' ': 2831},
#  'u': {'a': 30,
#   'b': 35,
#   'c': 187,
#   'd': 66,
#   'e': 169,
#   'f': 5,
#   'g': 175,
#   'h': 1,
#   'i': 90,
#   'j': 0,
#   'k': 5,
#   'l': 355,
#   'm': 60,
#   'n': 331,
#   'o': 3,
#   'p': 223,
#   'q': 0,
#   'r': 536,
#   's': 475,
#   't': 754,
#   'u': 0,
#   'v': 0,
#   'w': 2,
#   'x': 0,
#   'y': 0,
#   'z': 14,
#   ' ': 360},
#  'v': {'a': 29,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 765,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 97,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 70,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 1,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 3,
#   'z': 0,
#   ' ': 0},
#  'w': {'a': 601,
#   'b': 0,
#   'c': 1,
#   'd': 11,
#   'e': 365,
#   'f': 5,
#   'g': 0,
#   'h': 533,
#   'i': 450,
#   'j': 0,
#   'k': 1,
#   'l': 32,
#   'm': 1,
#   'n': 147,
#   'o': 358,
#   'p': 1,
#   'q': 1,
#   'r': 38,
#   's': 32,
#   't': 5,
#   'u': 0,
#   'v': 1,
#   'w': 16,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 231},
#  'x': {'a': 12,
#   'b': 0,
#   'c': 18,
#   'd': 0,
#   'e': 27,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 27,
#   'j': 0,
#   'k': 0,
#   'l': 0,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 31,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 42,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 0,
#   'z': 0,
#   ' ': 15},
#  'y': {'a': 34,
#   'b': 13,
#   'c': 13,
#   'd': 10,
#   'e': 104,
#   'f': 4,
#   'g': 3,
#   'h': 4,
#   'i': 67,
#   'j': 0,
#   'k': 2,
#   'l': 6,
#   'm': 10,
#   'n': 4,
#   'o': 591,
#   'p': 61,
#   'q': 0,
#   'r': 23,
#   's': 49,
#   't': 47,
#   'u': 3,
#   'v': 0,
#   'w': 9,
#   'x': 0,
#   'y': 3,
#   'z': 0,
#   ' ': 1112},
#  'z': {'a': 7,
#   'b': 0,
#   'c': 0,
#   'd': 0,
#   'e': 32,
#   'f': 0,
#   'g': 0,
#   'h': 0,
#   'i': 11,
#   'j': 0,
#   'k': 0,
#   'l': 14,
#   'm': 0,
#   'n': 0,
#   'o': 0,
#   'p': 0,
#   'q': 0,
#   'r': 0,
#   's': 0,
#   't': 0,
#   'u': 0,
#   'v': 0,
#   'w': 0,
#   'x': 0,
#   'y': 2,
#   'z': 14,
#   ' ': 0},
#  ' ': {'a': 3322,
#   'b': 912,
#   'c': 924,
#   'd': 846,
#   'e': 420,
#   'f': 785,
#   'g': 605,
#   'h': 1439,
#   'i': 1760,
#   'j': 108,
#   'k': 245,
#   'l': 744,
#   'm': 901,
#   'n': 536,
#   'o': 1543,
#   'p': 626,
#   'q': 171,
#   'r': 525,
#   's': 2369,
#   't': 4293,
#   'u': 299,
#   'v': 225,
#   'w': 1774,
#   'x': 6,
#   'y': 509,
#   'z': 2,
#   ' ': 173}}

# %%
# Start with space. SS - this will need changing to two characters, he suggested as much in the video
pairs = '  '

# Do the following N-1 times.
# I've changed this to 1000 just to restrict the view, and also because the output requires 1000 characters
for i in range(1, 1000):
    # Get the weights where the previous character is the last character in pairs.
    wt = twoghts[pairs[-1]]
    # Turn wt into a list, ordered by chars.
    wt = [wt[c] for c in chars]
    # Randomly pick the next character using those weights.
    nextc = random.choices(chars, weights=wt, k=1)[0]
    # Append the character to pairs.
    pairs = pairs + nextc
    
print(pairs)
# Out:
#   motrerabebe shinghe t kngithar anof mith amon d arsircth eeffinounnok oupprhel itheshelitathe t an ainedrourent itis ag goldusaicas owofom s w cale ar theaithmpo s ousedn sery in tens tier ithapedoweridof ou funthearth wisoieacthersherd as yirutheayouedd chesat llefevit tg f se o the fut alalatsherar d at s id thooolleraceerorathinosast rsorpo ri seree h fai f fen ptutuceg s thid windaseeid yoliesttinigext atutloriceng owo anteg eanoofes inl at tangit wn shad brar nd mo ingan an thar weas its ve pont s torkerndirderyo pershecomonqut y tthinkn in atorthesooucoethipemyowhed ai vine sotainthedoas epr pldhongsiceeolais nuryoredd s oulere knowouthond cly teth itherith ou ai t r je h von ielt owha o tt ote s nfof winienorat tusowaseldis id y drs d yofond walathe tct hidom bey a ty hinthe jen ig anelitacofueatheren widvein spouroft murpren athadrecofthe ad ve witord stait t s ther ichelithad doncad the p sto mor thionke t oit ulithas satsherirand theldrt then  qurpig an saic alend on ould th
